# %%
import numpy as np
import pandas as pd
import scipy
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.sample(3)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 2303   F    0.58     0.455   0.120        0.9400          0.3990
# 1529   M    0.74     0.570   0.180        1.8725          0.9115
# 3528   I    0.35     0.265   0.085        0.1735          0.0775
#
#       Viscera weight  Shell weight  Rings
# 2303           0.257         0.265     11
# 1529           0.427         0.446     10
# 3528           0.034         0.056      6

# %%
df.tail(2)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4175          0.2610         0.296     10
# 4176          0.3765         0.495     12

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df=pd.DataFrame(data=df)
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.isnull()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# 2              False         False  False
# 3              False         False  False
# 4              False         False  False
# ...              ...           ...    ...
# 4172           False         False  False
# 4173           False         False  False
# 4174           False         False  False
# 4175           False         False  False
# 4176           False         False  False
#
# [4177 rows x 9 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.displot(df['Diameter'])

# %%
sns.displot(df['Shell weight'])

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.iloc[:,0]
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
#        ..
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: Sex, Length: 4177, dtype: object

# %%
lencode=LabelEncoder()
df['Sex']=lencode.fit_transform(df['Sex'])
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
sns.displot(df['Height'])

# %%
sns.displot(df['Height'],bins=20)

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# Diameter              0.893162        0.899724      0.905330  0.574660
# Height                0.774972        0.798319      0.817338  0.557467
# Whole weight          0.969405        0.966375      0.955355  0.540390
# Shucked weight        1.000000        0.931961      0.882617  0.420884
# Viscera weight        0.931961        1.000000      0.907656  0.503819
# Shell weight          0.882617        0.907656      1.000000  0.627574
# Rings                 0.420884        0.503819      0.627574  1.000000

# %%
sns.heatmap(df.corr(),cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# 3             0.1140        0.1550
# 4             0.0395        0.0550
# ...              ...           ...
# 4172          0.2390        0.2490
# 4173          0.2145        0.2605
# 4174          0.2875        0.3080
# 4175          0.2610        0.2960
# 4176          0.3765        0.4950
#
# [4177 rows x 8 columns]

# %%
x.shape
# Out:
# (4177, 8)

# %%
x.shape[1]
# Out:
# 8

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif["features"]=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#    VIF Factor        features
# 0    2.555356             Sex
# 1  700.488988          Length
# 2  749.121626        Diameter
# 3   42.128924          Height
# 4  421.652484    Whole weight
# 5  101.674946  Shucked weight
# 6   63.585627  Viscera weight
# 7   81.873737    Shell weight

# %%
df.drop(['Length','Shucked weight'],axis=1,inplace=True)
df
# Out:
#       Sex  Diameter  Height  Whole weight  Viscera weight  Shell weight  Rings
# 0       2     0.365   0.095        0.5140          0.1010        0.1500     15
# 1       2     0.265   0.090        0.2255          0.0485        0.0700      7
# 2       0     0.420   0.135        0.6770          0.1415        0.2100      9
# 3       2     0.365   0.125        0.5160          0.1140        0.1550     10
# 4       1     0.255   0.080        0.2050          0.0395        0.0550      7
# ...   ...       ...     ...           ...             ...           ...    ...
# 4172    0     0.450   0.165        0.8870          0.2390        0.2490     11
# 4173    2     0.440   0.135        0.9660          0.2145        0.2605     10
# 4174    2     0.475   0.205        1.1760          0.2875        0.3080      9
# 4175    0     0.485   0.150        1.0945          0.2610        0.2960     10
# 4176    2     0.555   0.195        1.9485          0.3765        0.4950     12
#
# [4177 rows x 7 columns]

# %%
x=df.iloc[:,:-1]
x
# Out:
#       Sex  Diameter  Height  Whole weight  Viscera weight  Shell weight
# 0       2     0.365   0.095        0.5140          0.1010        0.1500
# 1       2     0.265   0.090        0.2255          0.0485        0.0700
# 2       0     0.420   0.135        0.6770          0.1415        0.2100
# 3       2     0.365   0.125        0.5160          0.1140        0.1550
# 4       1     0.255   0.080        0.2050          0.0395        0.0550
# ...   ...       ...     ...           ...             ...           ...
# 4172    0     0.450   0.165        0.8870          0.2390        0.2490
# 4173    2     0.440   0.135        0.9660          0.2145        0.2605
# 4174    2     0.475   0.205        1.1760          0.2875        0.3080
# 4175    0     0.485   0.150        1.0945          0.2610        0.2960
# 4176    2     0.555   0.195        1.9485          0.3765        0.4950
#
# [4177 rows x 6 columns]

# %%
x.shape
# Out:
# (4177, 6)

# %%
vif_calc()
# Out:
#    VIF Factor        features
# 0    2.532536             Sex
# 1   46.978990        Diameter
# 2   41.650431          Height
# 3  123.993316    Whole weight
# 4   59.292682  Viscera weight
# 5   49.403495    Shell weight

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# Sex              -0.098155
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 1.12707158, -0.54986033, -1.12451192, -0.57676568, -0.69328289,
#         -0.587809  ],
#        [ 1.12707158, -1.38733299, -1.26439579, -1.35176054, -1.33295268,
#         -1.33241968],
#        [-1.30793479,  0.00853714, -0.06482301, -0.19809927, -0.25513514,
#         -0.09826193],
#        ...,
#        [ 1.12707158,  0.64519089,  1.56508168,  0.77794363,  1.01560749,
#          0.59839786],
#        [-1.30793479,  0.76992788,  0.30708344,  0.63387374,  0.81518436,
#          0.51914542],
#        [ 1.12707158,  1.72628889,  1.34794324,  1.93732306,  1.61134422,
#          1.65848824]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.12707158, -0.54986033, -1.12451192, -0.57676568, -0.69328289,
#         -0.587809  ],
#        [ 1.12707158, -1.38733299, -1.26439579, -1.35176054, -1.33295268,
#         -1.33241968],
#        [-1.30793479,  0.00853714, -0.06482301, -0.19809927, -0.25513514,
#         -0.09826193],
#        ...,
#        [ 1.12707158,  0.64519089,  1.56508168,  0.77794363,  1.01560749,
#          0.59839786],
#        [-1.30793479,  0.76992788,  0.30708344,  0.63387374,  0.81518436,
#          0.51914542],
#        [ 1.12707158,  1.72628889,  1.34794324,  1.93732306,  1.61134422,
#          1.65848824]])

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (4177, 7)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  166,  166,
#         167,  168,  170,  181,  232,  236,  236,  237,  238,  270,  275,
#         277,  278,  294,  310,  313,  314,  334,  351,  355,  358,  358,
#         362,  375,  416,  417,  428,  431,  433,  469,  478,  480,  501,
#         526,  530,  572,  628,  673,  674,  675,  678,  694,  696,  719,
#         720,  744,  754,  756,  811,  891,  891, 1048, 1051, 1052, 1204,
#        1206, 1207, 1207, 1207, 1209, 1257, 1417, 1422, 1427, 1427, 1428,
#        1429, 1757, 1759, 1762, 1762, 1763, 1763, 1987, 2051, 2090, 2108,
#        2108, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209, 2274,
#        2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2436, 2459,
#        2471, 2623, 2624, 2624, 2709, 2710, 2810, 2811, 2811, 2863, 2863,
#        3008, 3140, 3148, 3149, 3149, 3151, 3151, 3188, 3193, 3280, 3359,
#        3427, 3427, 3599, 3628, 3715, 3715, 3715, 3800, 3837, 3899, 3924,
#        3930, 3944, 3996, 4145, 4148], dtype=int64), array([6, 6, 5, 6, 5, 5, 5, 3, 5, 5, 6, 6, 5, 4, 6, 6, 1, 2, 1, 1, 6, 6,
#        5, 6, 6, 6, 6, 6, 5, 6, 6, 3, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        1, 6, 6, 6, 6, 6, 6, 6, 1, 1, 1, 1, 6, 6, 6, 6, 3, 5, 4, 3, 3, 4,
#        4, 3, 4, 5, 3, 2, 2, 4, 3, 4, 5, 1, 4, 4, 3, 4, 3, 4, 1, 2, 5, 5,
#        6, 1, 5, 5, 6, 6, 6, 6, 5, 6, 5, 6, 6, 3, 4, 6, 6, 6, 6, 5, 6, 6,
#        6, 3, 3, 4, 4, 4, 4, 3, 4, 3, 4, 5, 6, 5, 5, 6, 5, 6, 5, 6, 6, 6,
#        3, 4, 3, 4, 3, 4, 5, 3, 1, 1, 6, 6, 6, 2, 5, 4], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       Sex  Diameter  Height  Whole weight  Viscera weight  Shell weight  Rings
# 0       2     0.365   0.095        0.5140          0.1010        0.1500     15
# 1       2     0.265   0.090        0.2255          0.0485        0.0700      7
# 2       0     0.420   0.135        0.6770          0.1415        0.2100      9
# 3       2     0.365   0.125        0.5160          0.1140        0.1550     10
# 4       1     0.255   0.080        0.2050          0.0395        0.0550      7
# ...   ...       ...     ...           ...             ...           ...    ...
# 4172    0     0.450   0.165        0.8870          0.2390        0.2490     11
# 4173    2     0.440   0.135        0.9660          0.2145        0.2605     10
# 4174    2     0.475   0.205        1.1760          0.2875        0.3080      9
# 4175    0     0.485   0.150        1.0945          0.2610        0.2960     10
# 4176    2     0.555   0.195        1.9485          0.3765        0.4950     12
#
# [4050 rows x 7 columns]

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (4177, 7)
# (4050, 7)

# %%
loss_percent=((4177-4050)/4177)*100
print(loss_percent)
# Out:
# 3.040459660043093

# %%
features=df.drop("Rings",axis=1)
target=df["Rings"]

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,1000):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i}, the training academy is:-{r2_score(target_train,pred_train)}")
    print(f"At random state {i}, the training academy is:-{r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, the training academy is:-0.4516563526425349
# At random state 0, the training academy is:-0.47989079848260174
#
#
# At random state 1, the training academy is:-0.4672774438894153
# At random state 1, the training academy is:-0.4190163442727467
#
#
# At random state 2, the training academy is:-0.45540604073374835
# At random state 2, the training academy is:-0.4416997793619841
#
#
# At random state 3, the training academy is:-0.46628668383616745
# At random state 3, the training academy is:-0.4214118054135424
#
#
# At random state 4, the training academy is:-0.46037598546335645
# At random state 4, the training academy is:-0.445636013759688
#
#
# At random state 5, the training academy is:-0.4735220679280304
# At random state 5, the training academy is:-0.3959254918103504
#
#
# At random state 6, the training academy is:-0.4465950421369501
# At random state 6, the training academy is:-0.5029772213081121
#
#
# At random state 7, the training academy is:-0.4512009249389275
# At random state 7, the training academy is:-0.4782091333200297
#
#
# At random state 8, the training academy is:-0.46369602998927384
# At random state 8, the training academy is:-0.43510904364219216
#
#
# At random state 9, the training academy is:-0.46521776944501747
# At random state 9, the training academy is:-0.4288050936269292
#
#
# At random state 10, the training academy is:-0.45562300723899785
# At random state 10, the training academy is:-0.46882977006545645
#
#
# At random state 11, the training academy is:-0.449916914026665
# At random state 11, the training academy is:-0.4895862364613095
#
#
# At random state 12, the training academy is:-0.4479667277030268
# At random state 12, the training academy is:-0.4948524727652853
#
#
# At random state 13, the training academy is:-0.45351172980395127
# At random state 13, the training academy is:-0.4767386990542992
#
#
# At random state 14, the training academy is:-0.46771001807306933
# At random state 14, the training academy is:-0.3893021076324008
#
#
# At random state 15, the training academy is:-0.46488095184091793
# At random state 15, the training academy is:-0.4303596738027664
#
#
# At random state 16, the training academy is:-0.4569928966250433
# At random state 16, the training academy is:-0.4638478273815516
#
#
# At random state 17, the training academy is:-0.44830858150523145
# At random state 17, the training academy is:-0.4927730254397521
#
#
# At random state 18, the training academy is:-0.46354515579859534
# At random state 18, the training academy is:-0.4371498533047996
#
#
# At random state 19, the training academy is:-0.47078905402268467
# At random state 19, the training academy is:-0.40620599420137515
#
#
# At random state 20, the training academy is:-0.46386524488212966
# At random state 20, the training academy is:-0.4352196060350856
#
#
# At random state 21, the training academy is:-0.45402408343300393
# At random state 21, the training academy is:-0.46957259025434717
#
#
# At random state 22, the training academy is:-0.4737528235345182
# At random state 22, the training academy is:-0.3581464513249072
#
#
# At random state 23, the training academy is:-0.4669278612972828
# At random state 23, the training academy is:-0.4211695920036186
#
#
# At random state 24, the training academy is:-0.4678860862323081
# At random state 24, the training academy is:-0.41101163536696994
#
#
# At random state 25, the training academy is:-0.47163671174326705
# At random state 25, the training academy is:-0.2997485505240529
#
#
# At random state 26, the training academy is:-0.4606839869183478
# At random state 26, the training academy is:-0.44904759202219746
#
#
# At random state 27, the training academy is:-0.46558836715135643
# At random state 27, the training academy is:-0.39285131346904634
#
#
# At random state 28, the training academy is:-0.45229650512803765
# At random state 28, the training academy is:-0.48129217301865634
#
#
# At random state 29, the training academy is:-0.45828618260399256
# At random state 29, the training academy is:-0.45831675893432255
#
#
# At random state 30, the training academy is:-0.44620779399298616
# At random state 30, the training academy is:-0.5012482619447061
#
#
# At random state 31, the training academy is:-0.4399742505256139
# At random state 31, the training academy is:-0.5183859786325937
#
#
# At random state 32, the training academy is:-0.45984736005661364
# At random state 32, the training academy is:-0.4523285298177475
#
#
# At random state 33, the training academy is:-0.45710454166132874
# At random state 33, the training academy is:-0.46033457783591747
#
#
# At random state 34, the training academy is:-0.4711305534002944
# At random state 34, the training academy is:-0.40066653097313387
#
#
# At random state 35, the training academy is:-0.4644822110660006
# At random state 35, the training academy is:-0.3906609936883927
#
#
# At random state 36, the training academy is:-0.46246882575461523
# At random state 36, the training academy is:-0.4395764801432004
#
#
# At random state 37, the training academy is:-0.44697618901129454
# At random state 37, the training academy is:-0.5056607453465256
#
#
# At random state 38, the training academy is:-0.45625362641420897
# At random state 38, the training academy is:-0.4640081263451694
#
#
# At random state 39, the training academy is:-0.46563643707994007
# At random state 39, the training academy is:-0.37473507287294183
#
#
# At random state 40, the training academy is:-0.45966013018646024
# At random state 40, the training academy is:-0.448218922355345
#
#
# At random state 41, the training academy is:-0.47393822961972076
# At random state 41, the training academy is:-0.3420558292151521
#
#
# At random state 42, the training academy is:-0.46153194498831085
# At random state 42, the training academy is:-0.44401276191475614
#
#
# At random state 43, the training academy is:-0.45069279776836013
# At random state 43, the training academy is:-0.49126007808887273
#
#
# At random state 44, the training academy is:-0.45949964491555173
# At random state 44, the training academy is:-0.452888125685885
#
#
# At random state 45, the training academy is:-0.46160669202717686
# At random state 45, the training academy is:-0.44209618148194685
#
#
# At random state 46, the training academy is:-0.459035144934947
# At random state 46, the training academy is:-0.4522646504976717
#
#
# At random state 47, the training academy is:-0.4741108971988566
# At random state 47, the training academy is:-0.3330427233326224
#
#
# At random state 48, the training academy is:-0.4546357463712243
# At random state 48, the training academy is:-0.4724523973820304
#
#
# At random state 49, the training academy is:-0.4636749710807586
# At random state 49, the training academy is:-0.4350544135634078
#
#
# At random state 50, the training academy is:-0.46425838797524765
# At random state 50, the training academy is:-0.39091088756878856
#
#
# At random state 51, the training academy is:-0.45719048840602394
# At random state 51, the training academy is:-0.4254965082649953
#
#
# At random state 52, the training academy is:-0.44976512430521165
# At random state 52, the training academy is:-0.49049677952682014
#
#
# At random state 53, the training academy is:-0.4519726227842401
# At random state 53, the training academy is:-0.4797620024479813
#
#
# At random state 54, the training academy is:-0.466660897532309
# At random state 54, the training academy is:-0.421105042936356
#
#
# At random state 55, the training academy is:-0.46139730951103775
# At random state 55, the training academy is:-0.4426806473687337
#
#
# At random state 56, the training academy is:-0.46496768115374676
# At random state 56, the training academy is:-0.3884488670520212
#
#
# At random state 57, the training academy is:-0.46674161152417326
# At random state 57, the training academy is:-0.3998143359376235
#
#
# At random state 58, the training academy is:-0.4507480721536876
# At random state 58, the training academy is:-0.485356676352545
#
#
# At random state 59, the training academy is:-0.45931201989913883
# At random state 59, the training academy is:-0.454037337225182
#
#
# At random state 60, the training academy is:-0.4616606928462532
# At random state 60, the training academy is:-0.4432493325565666
#
#
# At random state 61, the training academy is:-0.4616227407251059
# At random state 61, the training academy is:-0.39365707471937816
#
#
# At random state 62, the training academy is:-0.45584303989725083
# At random state 62, the training academy is:-0.4666524330292776
#
#
# At random state 63, the training academy is:-0.4696260123505138
# At random state 63, the training academy is:-0.3645622486390563
#
#
# At random state 64, the training academy is:-0.46233054804928087
# At random state 64, the training academy is:-0.44225898904569816
#
#
# At random state 65, the training academy is:-0.465832059015711
# At random state 65, the training academy is:-0.35786341013078315
#
#
# At random state 66, the training academy is:-0.4696042117610789
# At random state 66, the training academy is:-0.33776605666710324
#
#
# At random state 67, the training academy is:-0.45805739590671835
# At random state 67, the training academy is:-0.4574202598864018
#
#
# At random state 68, the training academy is:-0.4634809633040915
# At random state 68, the training academy is:-0.43664385682341733
#
#
# At random state 69, the training academy is:-0.45394475354726127
# At random state 69, the training academy is:-0.4724074748658559
#
#
# At random state 70, the training academy is:-0.46627668848964166
# At random state 70, the training academy is:-0.39139006385612696
#
#
# At random state 71, the training academy is:-0.45762148928429025
# At random state 71, the training academy is:-0.459597531514942
#
#
# At random state 72, the training academy is:-0.4656964355157105
# At random state 72, the training academy is:-0.42490077507153134
#
#
# At random state 73, the training academy is:-0.4668274756952021
# At random state 73, the training academy is:-0.42010501149780777
#
#
# At random state 74, the training academy is:-0.4620251912844937
# At random state 74, the training academy is:-0.4420244602435147
#
#
# At random state 75, the training academy is:-0.46208344572947024
# At random state 75, the training academy is:-0.44037579646693836
#
#
# At random state 76, the training academy is:-0.4577370492781936
# At random state 76, the training academy is:-0.4584806464247724
#
#
# At random state 77, the training academy is:-0.45190395345747036
# At random state 77, the training academy is:-0.48294347281926964
#
#
# At random state 78, the training academy is:-0.46847171164127144
# At random state 78, the training academy is:-0.4133281821000736
#
#
# At random state 79, the training academy is:-0.4568886591362784
# At random state 79, the training academy is:-0.46233409689907967
#
#
# At random state 80, the training academy is:-0.4688843191431181
# At random state 80, the training academy is:-0.41458890558880546
#
#
# At random state 81, the training academy is:-0.4455283035682035
# At random state 81, the training academy is:-0.5083871574793053
#
#
# At random state 82, the training academy is:-0.45371097762337176
# At random state 82, the training academy is:-0.4745448930240709
#
#
# At random state 83, the training academy is:-0.4605106942888002
# At random state 83, the training academy is:-0.44687822586461545
#
#
# At random state 84, the training academy is:-0.46211879265050615
# At random state 84, the training academy is:-0.44085262204368914
#
#
# At random state 85, the training academy is:-0.45697893729495165
# At random state 85, the training academy is:-0.45990512307043796
#
#
# At random state 86, the training academy is:-0.4717703038327038
# At random state 86, the training academy is:-0.3812658969929188
#
#
# At random state 87, the training academy is:-0.4626365317057243
# At random state 87, the training academy is:-0.43592611404638426
#
#
# At random state 88, the training academy is:-0.44751860379214514
# At random state 88, the training academy is:-0.49997498698111154
#
#
# At random state 89, the training academy is:-0.44796252882607135
# At random state 89, the training academy is:-0.49822092570523113
#
#
# At random state 90, the training academy is:-0.4598918140106626
# At random state 90, the training academy is:-0.4524940411596282
#
#
# At random state 91, the training academy is:-0.46288105118386524
# At random state 91, the training academy is:-0.4381915003821002
#
#
# At random state 92, the training academy is:-0.47722449894724916
# At random state 92, the training academy is:-0.350637638968226
#
#
# At random state 93, the training academy is:-0.45765044254376075
# At random state 93, the training academy is:-0.45779631382555686
#
#
# At random state 94, the training academy is:-0.4534733002918684
# At random state 94, the training academy is:-0.4740622127717883
#
#
# At random state 95, the training academy is:-0.45122091433662026
# At random state 95, the training academy is:-0.4842936222365011
#
#
# At random state 96, the training academy is:-0.4572846509523276
# At random state 96, the training academy is:-0.46272197099418455
#
#
# At random state 97, the training academy is:-0.4564829431365546
# At random state 97, the training academy is:-0.4653925378878274
#
#
# At random state 98, the training academy is:-0.4722145262359605
# At random state 98, the training academy is:-0.4011704650034018
#
#
# At random state 99, the training academy is:-0.4657506665766641
# At random state 99, the training academy is:-0.3842908142446264
#
#
# At random state 100, the training academy is:-0.4575843653411248
# At random state 100, the training academy is:-0.45875593494188005
#
#
# At random state 101, the training academy is:-0.46586331533756076
# At random state 101, the training academy is:-0.3882121445101404
#
#
# At random state 102, the training academy is:-0.45782122284619764
# At random state 102, the training academy is:-0.4484783461078993
#
#
# At random state 103, the training academy is:-0.4580501060464297
# At random state 103, the training academy is:-0.4574336916355529
#
#
# At random state 104, the training academy is:-0.46389123321533243
# At random state 104, the training academy is:-0.43399336087805995
#
#
# At random state 105, the training academy is:-0.4587764517857086
# At random state 105, the training academy is:-0.45616538407105334
#
#
# At random state 106, the training academy is:-0.46298818009188136
# At random state 106, the training academy is:-0.4076958381982727
#
#
# At random state 107, the training academy is:-0.46059871153532483
# At random state 107, the training academy is:-0.4476938555750406
#
#
# At random state 108, the training academy is:-0.46607877412141674
# At random state 108, the training academy is:-0.4219669301056431
#
#
# At random state 109, the training academy is:-0.4619102995063912
# At random state 109, the training academy is:-0.44294900027757556
#
#
# At random state 110, the training academy is:-0.46612158827940353
# At random state 110, the training academy is:-0.4281254914651643
#
#
# At random state 111, the training academy is:-0.4533544657496288
# At random state 111, the training academy is:-0.43936031344462856
#
#
# At random state 112, the training academy is:-0.4689865866611843
# At random state 112, the training academy is:-0.34013819585806615
#
#
# At random state 113, the training academy is:-0.46054735682694636
# At random state 113, the training academy is:-0.44966767250541995
#
#
# At random state 114, the training academy is:-0.4592127100207155
# At random state 114, the training academy is:-0.4499630497509891
#
#
# At random state 115, the training academy is:-0.4541409608442414
# At random state 115, the training academy is:-0.4738516341511848
#
#
# At random state 116, the training academy is:-0.45165740521430464
# At random state 116, the training academy is:-0.4815940622853201
#
#
# At random state 117, the training academy is:-0.47051970319311875
# At random state 117, the training academy is:-0.4072869605362016
#
#
# At random state 118, the training academy is:-0.4616024229885831
# At random state 118, the training academy is:-0.4427392673002646
#
#
# At random state 119, the training academy is:-0.45765638909358963
# At random state 119, the training academy is:-0.4592121035902903
#
#
# At random state 120, the training academy is:-0.45729576096711877
# At random state 120, the training academy is:-0.461099883772779
#
#
# At random state 121, the training academy is:-0.4569362912655728
# At random state 121, the training academy is:-0.43734835314062004
#
#
# At random state 122, the training academy is:-0.46378538059893226
# At random state 122, the training academy is:-0.4371402922237816
#
#
# At random state 123, the training academy is:-0.4517848982185886
# At random state 123, the training academy is:-0.48571536219234634
#
#
# At random state 124, the training academy is:-0.4593005619236896
# At random state 124, the training academy is:-0.4522026796010894
#
#
# At random state 125, the training academy is:-0.4526615422340494
# At random state 125, the training academy is:-0.4775415725918586
#
#
# At random state 126, the training academy is:-0.4589379190630727
# At random state 126, the training academy is:-0.45501631275766075
#
#
# At random state 127, the training academy is:-0.4620139946586952
# At random state 127, the training academy is:-0.44133329030055135
#
#
# At random state 128, the training academy is:-0.46920652077182
# At random state 128, the training academy is:-0.372917495414265
#
#
# At random state 129, the training academy is:-0.4705143198683881
# At random state 129, the training academy is:-0.37965298184719976
#
#
# At random state 130, the training academy is:-0.455603818771235
# At random state 130, the training academy is:-0.47038172216624685
#
#
# At random state 131, the training academy is:-0.4528756200344032
# At random state 131, the training academy is:-0.47876934419875605
#
#
# At random state 132, the training academy is:-0.4462712519559101
# At random state 132, the training academy is:-0.49938842190631016
#
#
# At random state 133, the training academy is:-0.4801443621876953
# At random state 133, the training academy is:-0.3428056988174023
#
#
# At random state 134, the training academy is:-0.4473189015810859
# At random state 134, the training academy is:-0.49824669077943395
#
#
# At random state 135, the training academy is:-0.46084261184964015
# At random state 135, the training academy is:-0.4469017597427153
#
#
# At random state 136, the training academy is:-0.47325715605745433
# At random state 136, the training academy is:-0.3233443912602647
#
#
# At random state 137, the training academy is:-0.4582443464261805
# At random state 137, the training academy is:-0.45597348292815254
#
#
# At random state 138, the training academy is:-0.46774080891294834
# At random state 138, the training academy is:-0.41706657388856394
#
#
# At random state 139, the training academy is:-0.47710773922766636
# At random state 139, the training academy is:-0.3399095533250628
#
#
# At random state 140, the training academy is:-0.4569802419092489
# At random state 140, the training academy is:-0.46318829392520156
#
#
# At random state 141, the training academy is:-0.45909877568320157
# At random state 141, the training academy is:-0.4531991664176801
#
#
# At random state 142, the training academy is:-0.45811623814775215
# At random state 142, the training academy is:-0.45692254835400226
#
#
# At random state 143, the training academy is:-0.4663069821071738
# At random state 143, the training academy is:-0.42457723863285923
#
#
# At random state 144, the training academy is:-0.4596931028261566
# At random state 144, the training academy is:-0.44868224944127
#
#
# At random state 145, the training academy is:-0.46955624237395754
# At random state 145, the training academy is:-0.37017999672743795
#
#
# At random state 146, the training academy is:-0.45653022773458185
# At random state 146, the training academy is:-0.4659416160422951
#
#
# At random state 147, the training academy is:-0.46741979476800255
# At random state 147, the training academy is:-0.38637651178728427
#
#
# At random state 148, the training academy is:-0.4484388482253042
# At random state 148, the training academy is:-0.4911976958648623
#
#
# At random state 149, the training academy is:-0.4643388274565483
# At random state 149, the training academy is:-0.4284681272607819
#
#
# At random state 150, the training academy is:-0.46361499302753173
# At random state 150, the training academy is:-0.43559656891925946
#
#
# At random state 151, the training academy is:-0.4696933856081784
# At random state 151, the training academy is:-0.4147658995125294
#
#
# At random state 152, the training academy is:-0.4526010465538426
# At random state 152, the training academy is:-0.4792765437617462
#
#
# At random state 153, the training academy is:-0.46363256891357507
# At random state 153, the training academy is:-0.43389393129083476
#
#
# At random state 154, the training academy is:-0.46485765696585835
# At random state 154, the training academy is:-0.4310832091666261
#
#
# At random state 155, the training academy is:-0.46520564928300345
# At random state 155, the training academy is:-0.4309067471323974
#
#
# At random state 156, the training academy is:-0.46238977881176857
# At random state 156, the training academy is:-0.3872328727335119
#
#
# At random state 157, the training academy is:-0.47093652713283085
# At random state 157, the training academy is:-0.3992926774017338
#
#
# At random state 158, the training academy is:-0.45158768311080744
# At random state 158, the training academy is:-0.4476190162906867
#
#
# At random state 159, the training academy is:-0.4526885352574479
# At random state 159, the training academy is:-0.4738297048490796
#
#
# At random state 160, the training academy is:-0.4621407173750115
# At random state 160, the training academy is:-0.44332845457587267
#
#
# At random state 161, the training academy is:-0.46501078701406673
# At random state 161, the training academy is:-0.43022457571554007
#
#
# At random state 162, the training academy is:-0.44823826124822197
# At random state 162, the training academy is:-0.4995730492307965
#
#
# At random state 163, the training academy is:-0.4720655765922096
# At random state 163, the training academy is:-0.40562798029045966
#
#
# At random state 164, the training academy is:-0.47277637327109234
# At random state 164, the training academy is:-0.3916818296632143
#
#
# At random state 165, the training academy is:-0.47974543099133904
# At random state 165, the training academy is:-0.34069808529462764
#
#
# At random state 166, the training academy is:-0.45636310318793627
# At random state 166, the training academy is:-0.46282802112326105
#
#
# At random state 167, the training academy is:-0.46224798912894915
# At random state 167, the training academy is:-0.43825448557864277
#
#
# At random state 168, the training academy is:-0.4478447538249799
# At random state 168, the training academy is:-0.49441621893710197
#
#
# At random state 169, the training academy is:-0.46790432784402747
# At random state 169, the training academy is:-0.3863598791080073
#
#
# At random state 170, the training academy is:-0.4516161498688521
# At random state 170, the training academy is:-0.48407722283956156
#
#
# At random state 171, the training academy is:-0.4564208128824857
# At random state 171, the training academy is:-0.4649417340143186
#
#
# At random state 172, the training academy is:-0.46337632912154947
# At random state 172, the training academy is:-0.3988900488458603
#
#
# At random state 173, the training academy is:-0.455676521618088
# At random state 173, the training academy is:-0.4123908272555815
#
#
# At random state 174, the training academy is:-0.4504391220388759
# At random state 174, the training academy is:-0.4889105740958435
#
#
# At random state 175, the training academy is:-0.4468452532574635
# At random state 175, the training academy is:-0.49648511669773365
#
#
# At random state 176, the training academy is:-0.4630633451545163
# At random state 176, the training academy is:-0.43879867982365584
#
#
# At random state 177, the training academy is:-0.4615436182951036
# At random state 177, the training academy is:-0.3995346033728767
#
#
# At random state 178, the training academy is:-0.4697083250469791
# At random state 178, the training academy is:-0.41482624181538696
#
#
# At random state 179, the training academy is:-0.4697664708061745
# At random state 179, the training academy is:-0.35171696357157867
#
#
# At random state 180, the training academy is:-0.45935063559470934
# At random state 180, the training academy is:-0.4485058213134506
#
#
# At random state 181, the training academy is:-0.45736466409017895
# At random state 181, the training academy is:-0.46199159879316287
#
#
# At random state 182, the training academy is:-0.4669498457335691
# At random state 182, the training academy is:-0.420732994537248
#
#
# At random state 183, the training academy is:-0.455724945901009
# At random state 183, the training academy is:-0.46672178258397223
#
#
# At random state 184, the training academy is:-0.4516150907013198
# At random state 184, the training academy is:-0.48783875332024107
#
#
# At random state 185, the training academy is:-0.4640793885902905
# At random state 185, the training academy is:-0.43415348614224514
#
#
# At random state 186, the training academy is:-0.4643087876408084
# At random state 186, the training academy is:-0.367894970497027
#
#
# At random state 187, the training academy is:-0.4488390789882356
# At random state 187, the training academy is:-0.5000909726828167
#
#
# At random state 188, the training academy is:-0.4575655679496612
# At random state 188, the training academy is:-0.4159512996296163
#
#
# At random state 189, the training academy is:-0.4575848808512234
# At random state 189, the training academy is:-0.45955276454072247
#
#
# At random state 190, the training academy is:-0.45920217520791295
# At random state 190, the training academy is:-0.4540390070924434
#
#
# At random state 191, the training academy is:-0.4622514502653733
# At random state 191, the training academy is:-0.43929222999078565
#
#
# At random state 192, the training academy is:-0.4527527173840038
# At random state 192, the training academy is:-0.47858607765631456
#
#
# At random state 193, the training academy is:-0.455958163369678
# At random state 193, the training academy is:-0.4664249153034703
#
#
# At random state 194, the training academy is:-0.45489749000868507
# At random state 194, the training academy is:-0.4683757684627846
#
#
# At random state 195, the training academy is:-0.46061820600106707
# At random state 195, the training academy is:-0.4478778762749315
#
#
# At random state 196, the training academy is:-0.450463895033286
# At random state 196, the training academy is:-0.4929583245619822
#
#
# At random state 197, the training academy is:-0.4614307096193072
# At random state 197, the training academy is:-0.4408177827785844
#
#
# At random state 198, the training academy is:-0.46725923521223844
# At random state 198, the training academy is:-0.40262188772167906
#
#
# At random state 199, the training academy is:-0.47031468649477004
# At random state 199, the training academy is:-0.41090279889870795
#
#
# At random state 200, the training academy is:-0.4671327748029125
# At random state 200, the training academy is:-0.37814454536162523
#
#
# At random state 201, the training academy is:-0.442478919241315
# At random state 201, the training academy is:-0.5211733812011079
#
#
# At random state 202, the training academy is:-0.46116583992562366
# At random state 202, the training academy is:-0.44537855872628085
#
#
# At random state 203, the training academy is:-0.45664752514973495
# At random state 203, the training academy is:-0.46126116732023514
#
#
# At random state 204, the training academy is:-0.4619776102115021
# At random state 204, the training academy is:-0.43757057456281767
#
#
# At random state 205, the training academy is:-0.4486582227968723
# At random state 205, the training academy is:-0.4911478390157614
#
#
# At random state 206, the training academy is:-0.4495270327401074
# At random state 206, the training academy is:-0.486101539720595
#
#
# At random state 207, the training academy is:-0.4612096495308069
# At random state 207, the training academy is:-0.4451596230607927
#
#
# At random state 208, the training academy is:-0.4466327789342095
# At random state 208, the training academy is:-0.5066709070459113
#
#
# At random state 209, the training academy is:-0.4645887962508597
# At random state 209, the training academy is:-0.43022605769976197
#
#
# At random state 210, the training academy is:-0.45819487721124996
# At random state 210, the training academy is:-0.45762470990219806
#
#
# At random state 211, the training academy is:-0.46019741463964325
# At random state 211, the training academy is:-0.4503779723904776
#
#
# At random state 212, the training academy is:-0.4561515025893259
# At random state 212, the training academy is:-0.4658102648586798
#
#
# At random state 213, the training academy is:-0.46880796039434314
# At random state 213, the training academy is:-0.40048813259914906
#
#
# At random state 214, the training academy is:-0.45176655051255044
# At random state 214, the training academy is:-0.4809133335714635
#
#
# At random state 215, the training academy is:-0.45690669769189796
# At random state 215, the training academy is:-0.4622996295498395
#
#
# At random state 216, the training academy is:-0.4729087989100298
# At random state 216, the training academy is:-0.3326976720937852
#
#
# At random state 217, the training academy is:-0.4661445887239293
# At random state 217, the training academy is:-0.3897282328446964
#
#
# At random state 218, the training academy is:-0.4542365721650552
# At random state 218, the training academy is:-0.4751600626163167
#
#
# At random state 219, the training academy is:-0.45592838673632996
# At random state 219, the training academy is:-0.46643649549764055
#
#
# At random state 220, the training academy is:-0.45977985039618996
# At random state 220, the training academy is:-0.4000222541399491
#
#
# At random state 221, the training academy is:-0.4620544412157258
# At random state 221, the training academy is:-0.4093518984820027
#
#
# At random state 222, the training academy is:-0.4545174081608877
# At random state 222, the training academy is:-0.4734952342200205
#
#
# At random state 223, the training academy is:-0.46582515054618845
# At random state 223, the training academy is:-0.37584861784463497
#
#
# At random state 224, the training academy is:-0.4775361057014509
# At random state 224, the training academy is:-0.3494326805393222
#
#
# At random state 225, the training academy is:-0.4644511657393705
# At random state 225, the training academy is:-0.4296740889244529
#
#
# At random state 226, the training academy is:-0.47131201107080056
# At random state 226, the training academy is:-0.33968684109042646
#
#
# At random state 227, the training academy is:-0.472655376589186
# At random state 227, the training academy is:-0.3911995140468477
#
#
# At random state 228, the training academy is:-0.4599634519986666
# At random state 228, the training academy is:-0.447949106825672
#
#
# At random state 229, the training academy is:-0.4538016323921257
# At random state 229, the training academy is:-0.47532151615377605
#
#
# At random state 230, the training academy is:-0.45731980576705755
# At random state 230, the training academy is:-0.4619226073434467
#
#
# At random state 231, the training academy is:-0.46484597016632934
# At random state 231, the training academy is:-0.399631069441427
#
#
# At random state 232, the training academy is:-0.45978536117590474
# At random state 232, the training academy is:-0.4493255816683772
#
#
# At random state 233, the training academy is:-0.4697684561075812
# At random state 233, the training academy is:-0.40613121155160337
#
#
# At random state 234, the training academy is:-0.4579144349834191
# At random state 234, the training academy is:-0.4577588714842302
#
#
# At random state 235, the training academy is:-0.4578811129314885
# At random state 235, the training academy is:-0.4582632372680876
#
#
# At random state 236, the training academy is:-0.47155758978995055
# At random state 236, the training academy is:-0.3619681715319587
#
#
# At random state 237, the training academy is:-0.4619287658230261
# At random state 237, the training academy is:-0.4436898860064521
#
#
# At random state 238, the training academy is:-0.4580553201423059
# At random state 238, the training academy is:-0.4579374377769112
#
#
# At random state 239, the training academy is:-0.4575925006016429
# At random state 239, the training academy is:-0.4593445303415412
#
#
# At random state 240, the training academy is:-0.4600372445535038
# At random state 240, the training academy is:-0.44938060879054653
#
#
# At random state 241, the training academy is:-0.46142010117208265
# At random state 241, the training academy is:-0.40897445478254424
#
#
# At random state 242, the training academy is:-0.47029437931430196
# At random state 242, the training academy is:-0.37678492267086194
#
#
# At random state 243, the training academy is:-0.45847722143366254
# At random state 243, the training academy is:-0.41803663240654354
#
#
# At random state 244, the training academy is:-0.47088016202996497
# At random state 244, the training academy is:-0.3972972920620781
#
#
# At random state 245, the training academy is:-0.4522814510370564
# At random state 245, the training academy is:-0.48184103190378835
#
#
# At random state 246, the training academy is:-0.45127451226165705
# At random state 246, the training academy is:-0.4841034370927848
#
#
# At random state 247, the training academy is:-0.45488927856217976
# At random state 247, the training academy is:-0.47228414642683003
#
#
# At random state 248, the training academy is:-0.4729766615938128
# At random state 248, the training academy is:-0.38751113656265723
#
#
# At random state 249, the training academy is:-0.4602023041003751
# At random state 249, the training academy is:-0.4494509699274676
#
#
# At random state 250, the training academy is:-0.458651580846723
# At random state 250, the training academy is:-0.45423091283095474
#
#
# At random state 251, the training academy is:-0.46345169264857233
# At random state 251, the training academy is:-0.43385841408701586
#
#
# At random state 252, the training academy is:-0.44839163021193085
# At random state 252, the training academy is:-0.49605482420710556
#
#
# At random state 253, the training academy is:-0.4544617891968039
# At random state 253, the training academy is:-0.47205049968978874
#
#
# At random state 254, the training academy is:-0.4625728977903375
# At random state 254, the training academy is:-0.43916316026722757
#
#
# At random state 255, the training academy is:-0.45818992157229244
# At random state 255, the training academy is:-0.4524156896041093
#
#
# At random state 256, the training academy is:-0.4608386607628995
# At random state 256, the training academy is:-0.44755622217339985
#
#
# At random state 257, the training academy is:-0.4534183161665265
# At random state 257, the training academy is:-0.47615283967682864
#
#
# At random state 258, the training academy is:-0.46004542033783036
# At random state 258, the training academy is:-0.44682722163604927
#
#
# At random state 259, the training academy is:-0.4625112018520986
# At random state 259, the training academy is:-0.3706634640013632
#
#
# At random state 260, the training academy is:-0.44990753853797016
# At random state 260, the training academy is:-0.48465702832604296
#
#
# At random state 261, the training academy is:-0.45860951483768164
# At random state 261, the training academy is:-0.4552315768394173
#
#
# At random state 262, the training academy is:-0.4466489831996837
# At random state 262, the training academy is:-0.49950109138197396
#
#
# At random state 263, the training academy is:-0.4638068890882744
# At random state 263, the training academy is:-0.4062731641117774
#
#
# At random state 264, the training academy is:-0.4570194338598488
# At random state 264, the training academy is:-0.4606099590092678
#
#
# At random state 265, the training academy is:-0.4443420824466664
# At random state 265, the training academy is:-0.5064194653002798
#
#
# At random state 266, the training academy is:-0.46771592734536627
# At random state 266, the training academy is:-0.4201723021035222
#
#
# At random state 267, the training academy is:-0.4627668469740771
# At random state 267, the training academy is:-0.4386257580433611
#
#
# At random state 268, the training academy is:-0.4578998333801958
# At random state 268, the training academy is:-0.45883984828573954
#
#
# At random state 269, the training academy is:-0.4598337741471855
# At random state 269, the training academy is:-0.4175153013800301
#
#
# At random state 270, the training academy is:-0.46104666191504706
# At random state 270, the training academy is:-0.4087727705668105
#
#
# At random state 271, the training academy is:-0.45055203706600655
# At random state 271, the training academy is:-0.49115616432657827
#
#
# At random state 272, the training academy is:-0.4494354143947087
# At random state 272, the training academy is:-0.4956454440431234
#
#
# At random state 273, the training academy is:-0.4640003775748074
# At random state 273, the training academy is:-0.3948665124278754
#
#
# At random state 274, the training academy is:-0.4569004377596806
# At random state 274, the training academy is:-0.46235211379190844
#
#
# At random state 275, the training academy is:-0.4643982141380947
# At random state 275, the training academy is:-0.431788836584428
#
#
# At random state 276, the training academy is:-0.4646729166476654
# At random state 276, the training academy is:-0.3829331882398199
#
#
# At random state 277, the training academy is:-0.4617379214514561
# At random state 277, the training academy is:-0.4443283910826734
#
#
# At random state 278, the training academy is:-0.45634948610749737
# At random state 278, the training academy is:-0.463956256492993
#
#
# At random state 279, the training academy is:-0.4602025648335638
# At random state 279, the training academy is:-0.4483052389273908
#
#
# At random state 280, the training academy is:-0.44457144201250365
# At random state 280, the training academy is:-0.5058501853354102
#
#
# At random state 281, the training academy is:-0.47167122329910205
# At random state 281, the training academy is:-0.34393587037796347
#
#
# At random state 282, the training academy is:-0.450701012123749
# At random state 282, the training academy is:-0.4869929029323993
#
#
# At random state 283, the training academy is:-0.450476921196867
# At random state 283, the training academy is:-0.4888090652120831
#
#
# At random state 284, the training academy is:-0.4564287131288043
# At random state 284, the training academy is:-0.4631296612752719
#
#
# At random state 285, the training academy is:-0.46372095451066053
# At random state 285, the training academy is:-0.416020914873412
#
#
# At random state 286, the training academy is:-0.4539113245635439
# At random state 286, the training academy is:-0.47302817077321513
#
#
# At random state 287, the training academy is:-0.4527337654965652
# At random state 287, the training academy is:-0.47723409825314034
#
#
# At random state 288, the training academy is:-0.45627797745597476
# At random state 288, the training academy is:-0.464433581697399
#
#
# At random state 289, the training academy is:-0.45389775557626
# At random state 289, the training academy is:-0.4747740443287315
#
#
# At random state 290, the training academy is:-0.45956707112208095
# At random state 290, the training academy is:-0.4489679673576378
#
#
# At random state 291, the training academy is:-0.47337571059131434
# At random state 291, the training academy is:-0.33631132947828835
#
#
# At random state 292, the training academy is:-0.4667020965841878
# At random state 292, the training academy is:-0.39490928959713745
#
#
# At random state 293, the training academy is:-0.4691369890611162
# At random state 293, the training academy is:-0.37727276730536485
#
#
# At random state 294, the training academy is:-0.47055244887395264
# At random state 294, the training academy is:-0.34509496139262363
#
#
# At random state 295, the training academy is:-0.45971550631232305
# At random state 295, the training academy is:-0.4186384744953813
#
#
# At random state 296, the training academy is:-0.4535064313497307
# At random state 296, the training academy is:-0.4758874371303472
#
#
# At random state 297, the training academy is:-0.4531523311539859
# At random state 297, the training academy is:-0.47903833134370155
#
#
# At random state 298, the training academy is:-0.4612657850469716
# At random state 298, the training academy is:-0.44553886084365313
#
#
# At random state 299, the training academy is:-0.4593100025871101
# At random state 299, the training academy is:-0.4533742741072029
#
#
# At random state 300, the training academy is:-0.4623756707732246
# At random state 300, the training academy is:-0.437592050947334
#
#
# At random state 301, the training academy is:-0.456616271786913
# At random state 301, the training academy is:-0.4639422486063365
#
#
# At random state 302, the training academy is:-0.45317818875321114
# At random state 302, the training academy is:-0.48112582706660334
#
#
# At random state 303, the training academy is:-0.45666151704406854
# At random state 303, the training academy is:-0.46251812377591117
#
#
# At random state 304, the training academy is:-0.4696933158400317
# At random state 304, the training academy is:-0.39913144097201436
#
#
# At random state 305, the training academy is:-0.46652881114868006
# At random state 305, the training academy is:-0.4252413377372063
#
#
# At random state 306, the training academy is:-0.4714824346819695
# At random state 306, the training academy is:-0.37606446737820654
#
#
# At random state 307, the training academy is:-0.4528384260475208
# At random state 307, the training academy is:-0.4726459448889847
#
#
# At random state 308, the training academy is:-0.45462650537686466
# At random state 308, the training academy is:-0.4712150871689419
#
#
# At random state 309, the training academy is:-0.458011849359204
# At random state 309, the training academy is:-0.4583329850330162
#
#
# At random state 310, the training academy is:-0.460855311366666
# At random state 310, the training academy is:-0.44558651170026164
#
#
# At random state 311, the training academy is:-0.45459696548113304
# At random state 311, the training academy is:-0.472451092055469
#
#
# At random state 312, the training academy is:-0.45668837755714475
# At random state 312, the training academy is:-0.4636258315069488
#
#
# At random state 313, the training academy is:-0.46145894873377313
# At random state 313, the training academy is:-0.445636565768767
#
#
# At random state 314, the training academy is:-0.4501475637248974
# At random state 314, the training academy is:-0.49113924204422155
#
#
# At random state 315, the training academy is:-0.45268674837921785
# At random state 315, the training academy is:-0.4776199612022196
#
#
# At random state 316, the training academy is:-0.43356127184675375
# At random state 316, the training academy is:-0.5417899909441403
#
#
# At random state 317, the training academy is:-0.45502462489882634
# At random state 317, the training academy is:-0.46556797723068377
#
#
# At random state 318, the training academy is:-0.4696189177258915
# At random state 318, the training academy is:-0.3967143091072125
#
#
# At random state 319, the training academy is:-0.46570537873892737
# At random state 319, the training academy is:-0.42580720066149125
#
#
# At random state 320, the training academy is:-0.4418156941005916
# At random state 320, the training academy is:-0.5211655172522165
#
#
# At random state 321, the training academy is:-0.4588481371000994
# At random state 321, the training academy is:-0.4547051392014687
#
#
# At random state 322, the training academy is:-0.4647151331417856
# At random state 322, the training academy is:-0.3639496820697391
#
#
# At random state 323, the training academy is:-0.4562253194341017
# At random state 323, the training academy is:-0.4167402583944829
#
#
# At random state 324, the training academy is:-0.4608298150205262
# At random state 324, the training academy is:-0.44390037626243295
#
#
# At random state 325, the training academy is:-0.45003273672599486
# At random state 325, the training academy is:-0.48762794968905987
#
#
# At random state 326, the training academy is:-0.45721673389652573
# At random state 326, the training academy is:-0.4616450000623943
#
#
# At random state 327, the training academy is:-0.4678407516866544
# At random state 327, the training academy is:-0.34933709014671066
#
#
# At random state 328, the training academy is:-0.4728614234954811
# At random state 328, the training academy is:-0.40600354380869896
#
#
# At random state 329, the training academy is:-0.45921963566334334
# At random state 329, the training academy is:-0.4539173090419705
#
#
# At random state 330, the training academy is:-0.4719397134983785
# At random state 330, the training academy is:-0.36490247585606783
#
#
# At random state 331, the training academy is:-0.4460408165076426
# At random state 331, the training academy is:-0.4973616189096226
#
#
# At random state 332, the training academy is:-0.47269706682253776
# At random state 332, the training academy is:-0.35190739432008533
#
#
# At random state 333, the training academy is:-0.45588996297329387
# At random state 333, the training academy is:-0.4646313104570272
#
#
# At random state 334, the training academy is:-0.46561651217558697
# At random state 334, the training academy is:-0.42736357141465087
#
#
# At random state 335, the training academy is:-0.4641203255266112
# At random state 335, the training academy is:-0.43168834048520843
#
#
# At random state 336, the training academy is:-0.45353551148469773
# At random state 336, the training academy is:-0.47660267779807874
#
#
# At random state 337, the training academy is:-0.45525088516675427
# At random state 337, the training academy is:-0.4684411008905398
#
#
# At random state 338, the training academy is:-0.44746511611927453
# At random state 338, the training academy is:-0.49582013360821386
#
#
# At random state 339, the training academy is:-0.4609826909451531
# At random state 339, the training academy is:-0.4454731207546643
#
#
# At random state 340, the training academy is:-0.4652154953795947
# At random state 340, the training academy is:-0.42495880269565356
#
#
# At random state 341, the training academy is:-0.4466904087448079
# At random state 341, the training academy is:-0.5000454737941409
#
#
# At random state 342, the training academy is:-0.4533429744218539
# At random state 342, the training academy is:-0.4801124207384232
#
#
# At random state 343, the training academy is:-0.4591913223134728
# At random state 343, the training academy is:-0.453475471803255
#
#
# At random state 344, the training academy is:-0.46245799938660226
# At random state 344, the training academy is:-0.4384703800121609
#
#
# At random state 345, the training academy is:-0.4658636534708439
# At random state 345, the training academy is:-0.4250453042212906
#
#
# At random state 346, the training academy is:-0.45220118831342915
# At random state 346, the training academy is:-0.4798426504119848
#
#
# At random state 347, the training academy is:-0.4634395935714586
# At random state 347, the training academy is:-0.43644126875996214
#
#
# At random state 348, the training academy is:-0.46033003922350213
# At random state 348, the training academy is:-0.4236926626363764
#
#
# At random state 349, the training academy is:-0.4601529029778958
# At random state 349, the training academy is:-0.44614089662017065
#
#
# At random state 350, the training academy is:-0.46153860045438966
# At random state 350, the training academy is:-0.4445419015785286
#
#
# At random state 351, the training academy is:-0.47683736441513747
# At random state 351, the training academy is:-0.35994835954011506
#
#
# At random state 352, the training academy is:-0.4516627093936889
# At random state 352, the training academy is:-0.4803284383990003
#
#
# At random state 353, the training academy is:-0.46176294181533917
# At random state 353, the training academy is:-0.4422227141508025
#
#
# At random state 354, the training academy is:-0.46236544412793934
# At random state 354, the training academy is:-0.44082498700477646
#
#
# At random state 355, the training academy is:-0.45121047191904795
# At random state 355, the training academy is:-0.4834497815586749
#
#
# At random state 356, the training academy is:-0.46341627869344026
# At random state 356, the training academy is:-0.43787721286973624
#
#
# At random state 357, the training academy is:-0.4625446388589721
# At random state 357, the training academy is:-0.40651266046732093
#
#
# At random state 358, the training academy is:-0.44384341151129725
# At random state 358, the training academy is:-0.5128818996193547
#
#
# At random state 359, the training academy is:-0.46509291853606116
# At random state 359, the training academy is:-0.4231334487395666
#
#
# At random state 360, the training academy is:-0.4575835438084773
# At random state 360, the training academy is:-0.456601150475501
#
#
# At random state 361, the training academy is:-0.45682929710744746
# At random state 361, the training academy is:-0.4624615516418674
#
#
# At random state 362, the training academy is:-0.4691627765212032
# At random state 362, the training academy is:-0.3919666664574555
#
#
# ...
# At random state 879, the training academy is:-0.4462733450370838
#
#
# At random state 880, the training academy is:-0.45587692345856534
# At random state 880, the training academy is:-0.4650906946827633
#
#
# At random state 881, the training academy is:-0.4448032464385423
# At random state 881, the training academy is:-0.509498786484432
#
#
# At random state 882, the training academy is:-0.46225451394756967
# At random state 882, the training academy is:-0.4413331981872185
#
#
# At random state 883, the training academy is:-0.45567550283510627
# At random state 883, the training academy is:-0.4687236825704427
#
#
# At random state 884, the training academy is:-0.4614031961208611
# At random state 884, the training academy is:-0.4330772643640093
#
#
# At random state 885, the training academy is:-0.47107844746534133
# At random state 885, the training academy is:-0.3951700510001779
#
#
# At random state 886, the training academy is:-0.4624014548854146
# At random state 886, the training academy is:-0.4403767524259231
#
#
# At random state 887, the training academy is:-0.45490317290446347
# At random state 887, the training academy is:-0.47093877515118787
#
#
# At random state 888, the training academy is:-0.4579911253896739
# At random state 888, the training academy is:-0.4148841028089083
#
#
# At random state 889, the training academy is:-0.4664790584165639
# At random state 889, the training academy is:-0.38421978626674247
#
#
# At random state 890, the training academy is:-0.4572380448586618
# At random state 890, the training academy is:-0.46099720974981306
#
#
# At random state 891, the training academy is:-0.45758327782355834
# At random state 891, the training academy is:-0.4586319309074166
#
#
# At random state 892, the training academy is:-0.4735738060824749
# At random state 892, the training academy is:-0.28696274616971573
#
#
# At random state 893, the training academy is:-0.44359560213264126
# At random state 893, the training academy is:-0.5085651548995194
#
#
# At random state 894, the training academy is:-0.4606476978367807
# At random state 894, the training academy is:-0.44568302701080087
#
#
# At random state 895, the training academy is:-0.47353290626691713
# At random state 895, the training academy is:-0.3679538281268697
#
#
# At random state 896, the training academy is:-0.4631553957313598
# At random state 896, the training academy is:-0.43660689480372883
#
#
# At random state 897, the training academy is:-0.4701864610800902
# At random state 897, the training academy is:-0.41222422016056426
#
#
# At random state 898, the training academy is:-0.4486579168139547
# At random state 898, the training academy is:-0.49281009056852676
#
#
# At random state 899, the training academy is:-0.45918350776320294
# At random state 899, the training academy is:-0.45390051579314883
#
#
# At random state 900, the training academy is:-0.4594920149216102
# At random state 900, the training academy is:-0.45283561582755116
#
#
# At random state 901, the training academy is:-0.4533383152257531
# At random state 901, the training academy is:-0.4790570413668451
#
#
# At random state 902, the training academy is:-0.4665306560158866
# At random state 902, the training academy is:-0.4228690880147882
#
#
# At random state 903, the training academy is:-0.46091487178222224
# At random state 903, the training academy is:-0.44685611520252133
#
#
# At random state 904, the training academy is:-0.4555616717924421
# At random state 904, the training academy is:-0.4667712369858962
#
#
# At random state 905, the training academy is:-0.4493139479986704
# At random state 905, the training academy is:-0.49288191225125
#
#
# At random state 906, the training academy is:-0.4588864600232909
# At random state 906, the training academy is:-0.45478193931376865
#
#
# At random state 907, the training academy is:-0.4631770077176466
# At random state 907, the training academy is:-0.4315215027487139
#
#
# At random state 908, the training academy is:-0.4600106486118235
# At random state 908, the training academy is:-0.4482279891505614
#
#
# At random state 909, the training academy is:-0.4484121595025399
# At random state 909, the training academy is:-0.49423609917000333
#
#
# At random state 910, the training academy is:-0.46775075221081086
# At random state 910, the training academy is:-0.41563247714270213
#
#
# At random state 911, the training academy is:-0.47541477847656866
# At random state 911, the training academy is:-0.3516743796490578
#
#
# At random state 912, the training academy is:-0.46503534139680136
# At random state 912, the training academy is:-0.39608490261594675
#
#
# At random state 913, the training academy is:-0.46190674470423987
# At random state 913, the training academy is:-0.37282604085417526
#
#
# At random state 914, the training academy is:-0.45651405583587823
# At random state 914, the training academy is:-0.46507097860898405
#
#
# At random state 915, the training academy is:-0.4441543798955748
# At random state 915, the training academy is:-0.5009855745521481
#
#
# At random state 916, the training academy is:-0.462267131122693
# At random state 916, the training academy is:-0.39356367188446284
#
#
# At random state 917, the training academy is:-0.4517635051782296
# At random state 917, the training academy is:-0.482722841522774
#
#
# At random state 918, the training academy is:-0.4689327201733159
# At random state 918, the training academy is:-0.4166138456102064
#
#
# At random state 919, the training academy is:-0.4615737586658989
# At random state 919, the training academy is:-0.43814492032168084
#
#
# At random state 920, the training academy is:-0.45916976203029847
# At random state 920, the training academy is:-0.4534145517145116
#
#
# At random state 921, the training academy is:-0.46537370152816304
# At random state 921, the training academy is:-0.429222777287004
#
#
# At random state 922, the training academy is:-0.45699822826638303
# At random state 922, the training academy is:-0.46136371505919305
#
#
# At random state 923, the training academy is:-0.4471630002432364
# At random state 923, the training academy is:-0.5027917200876139
#
#
# At random state 924, the training academy is:-0.4411033548257559
# At random state 924, the training academy is:-0.5239479811617168
#
#
# At random state 925, the training academy is:-0.45786972737999165
# At random state 925, the training academy is:-0.45732008065187624
#
#
# At random state 926, the training academy is:-0.4682511375934947
# At random state 926, the training academy is:-0.3916905893183642
#
#
# At random state 927, the training academy is:-0.4648158800132365
# At random state 927, the training academy is:-0.4274241006867988
#
#
# At random state 928, the training academy is:-0.46010479963467166
# At random state 928, the training academy is:-0.4494803707870795
#
#
# At random state 929, the training academy is:-0.46561236972974807
# At random state 929, the training academy is:-0.3842486880881274
#
#
# At random state 930, the training academy is:-0.4625850310333116
# At random state 930, the training academy is:-0.38995994117763033
#
#
# At random state 931, the training academy is:-0.4697295866579244
# At random state 931, the training academy is:-0.4111464941229409
#
#
# At random state 932, the training academy is:-0.44339775253314717
# At random state 932, the training academy is:-0.5147714911159766
#
#
# At random state 933, the training academy is:-0.469906015557053
# At random state 933, the training academy is:-0.3783608865154676
#
#
# At random state 934, the training academy is:-0.4551295840745164
# At random state 934, the training academy is:-0.47029425273637027
#
#
# At random state 935, the training academy is:-0.4654047594164098
# At random state 935, the training academy is:-0.4303450709620291
#
#
# At random state 936, the training academy is:-0.4583299346746572
# At random state 936, the training academy is:-0.4197949113611853
#
#
# At random state 937, the training academy is:-0.4666449564808184
# At random state 937, the training academy is:-0.42421443659173874
#
#
# At random state 938, the training academy is:-0.4594437773064427
# At random state 938, the training academy is:-0.45091031910399626
#
#
# At random state 939, the training academy is:-0.4501897428581285
# At random state 939, the training academy is:-0.46201601435033335
#
#
# At random state 940, the training academy is:-0.44429732334383254
# At random state 940, the training academy is:-0.5064553210382656
#
#
# At random state 941, the training academy is:-0.4628839335701427
# At random state 941, the training academy is:-0.43939432653012367
#
#
# At random state 942, the training academy is:-0.46194016084321043
# At random state 942, the training academy is:-0.4056254457332219
#
#
# At random state 943, the training academy is:-0.4572915205318776
# At random state 943, the training academy is:-0.4624179588388382
#
#
# At random state 944, the training academy is:-0.4645937958245824
# At random state 944, the training academy is:-0.4343926548383291
#
#
# At random state 945, the training academy is:-0.46894851709973107
# At random state 945, the training academy is:-0.41762323609148766
#
#
# At random state 946, the training academy is:-0.464282526105087
# At random state 946, the training academy is:-0.4318483132631925
#
#
# At random state 947, the training academy is:-0.46239788088859846
# At random state 947, the training academy is:-0.396479800472302
#
#
# At random state 948, the training academy is:-0.47475868830801593
# At random state 948, the training academy is:-0.3329071153141331
#
#
# At random state 949, the training academy is:-0.46077662773261874
# At random state 949, the training academy is:-0.44756883430978145
#
#
# At random state 950, the training academy is:-0.4664764587750708
# At random state 950, the training academy is:-0.4239333078623445
#
#
# At random state 951, the training academy is:-0.458366199717233
# At random state 951, the training academy is:-0.4563105751917985
#
#
# At random state 952, the training academy is:-0.4665215773813399
# At random state 952, the training academy is:-0.4210618117398637
#
#
# At random state 953, the training academy is:-0.471535696584358
# At random state 953, the training academy is:-0.355004354142301
#
#
# At random state 954, the training academy is:-0.45811069329509513
# At random state 954, the training academy is:-0.4587306838051174
#
#
# At random state 955, the training academy is:-0.46739954702136655
# At random state 955, the training academy is:-0.42167357194787036
#
#
# At random state 956, the training academy is:-0.4701447761992785
# At random state 956, the training academy is:-0.39659821238660775
#
#
# At random state 957, the training academy is:-0.45290845178877315
# At random state 957, the training academy is:-0.47686855843926423
#
#
# At random state 958, the training academy is:-0.4450106386783661
# At random state 958, the training academy is:-0.5106957384257018
#
#
# At random state 959, the training academy is:-0.4621403938335418
# At random state 959, the training academy is:-0.44199188730971317
#
#
# At random state 960, the training academy is:-0.45069602818616583
# At random state 960, the training academy is:-0.4884812841131939
#
#
# At random state 961, the training academy is:-0.4625576860488413
# At random state 961, the training academy is:-0.44201738851928485
#
#
# At random state 962, the training academy is:-0.4728815110025162
# At random state 962, the training academy is:-0.3436043828903017
#
#
# At random state 963, the training academy is:-0.46849506022010845
# At random state 963, the training academy is:-0.37230065094582576
#
#
# At random state 964, the training academy is:-0.45816192857223215
# At random state 964, the training academy is:-0.4581069771361759
#
#
# At random state 965, the training academy is:-0.45923687055474227
# At random state 965, the training academy is:-0.4528954463282514
#
#
# At random state 966, the training academy is:-0.4599811589804663
# At random state 966, the training academy is:-0.4169448407109656
#
#
# At random state 967, the training academy is:-0.46732172548767104
# At random state 967, the training academy is:-0.3957621061439729
#
#
# At random state 968, the training academy is:-0.4624141041607749
# At random state 968, the training academy is:-0.4403506371986311
#
#
# At random state 969, the training academy is:-0.45858395848081224
# At random state 969, the training academy is:-0.4567292380559952
#
#
# At random state 970, the training academy is:-0.45906546702210893
# At random state 970, the training academy is:-0.45478913921518604
#
#
# At random state 971, the training academy is:-0.4533438106140858
# At random state 971, the training academy is:-0.47557451907184356
#
#
# At random state 972, the training academy is:-0.4560349651822664
# At random state 972, the training academy is:-0.46305635239687803
#
#
# At random state 973, the training academy is:-0.4505475093170387
# At random state 973, the training academy is:-0.4938864744164977
#
#
# At random state 974, the training academy is:-0.45850975819116246
# At random state 974, the training academy is:-0.45682453222829733
#
#
# At random state 975, the training academy is:-0.45946797223455516
# At random state 975, the training academy is:-0.4528365838657994
#
#
# At random state 976, the training academy is:-0.4461721583420408
# At random state 976, the training academy is:-0.5060334470895924
#
#
# At random state 977, the training academy is:-0.4532933092667497
# At random state 977, the training academy is:-0.47179577744534873
#
#
# At random state 978, the training academy is:-0.45963784448625866
# At random state 978, the training academy is:-0.45203707528791726
#
#
# At random state 979, the training academy is:-0.4559347884548365
# At random state 979, the training academy is:-0.46764140847036473
#
#
# At random state 980, the training academy is:-0.45562586793636284
# At random state 980, the training academy is:-0.4652729579464242
#
#
# At random state 981, the training academy is:-0.47464867000739963
# At random state 981, the training academy is:-0.3555656151086347
#
#
# At random state 982, the training academy is:-0.4640929970066514
# At random state 982, the training academy is:-0.4360414957189628
#
#
# At random state 983, the training academy is:-0.4519582567683391
# At random state 983, the training academy is:-0.48139651671449646
#
#
# At random state 984, the training academy is:-0.45460391270346345
# At random state 984, the training academy is:-0.4732095657251849
#
#
# At random state 985, the training academy is:-0.4619116631769743
# At random state 985, the training academy is:-0.44296796884788514
#
#
# At random state 986, the training academy is:-0.4652446361923994
# At random state 986, the training academy is:-0.3924169938208497
#
#
# At random state 987, the training academy is:-0.45314282193898714
# At random state 987, the training academy is:-0.4778464873057484
#
#
# At random state 988, the training academy is:-0.45478817194053134
# At random state 988, the training academy is:-0.4707957588543643
#
#
# At random state 989, the training academy is:-0.46075925141787666
# At random state 989, the training academy is:-0.44541292597200466
#
#
# At random state 990, the training academy is:-0.45207882559661994
# At random state 990, the training academy is:-0.48561009528329224
#
#
# At random state 991, the training academy is:-0.4704194852512982
# At random state 991, the training academy is:-0.3579956707655171
#
#
# At random state 992, the training academy is:-0.45329762099238147
# At random state 992, the training academy is:-0.47605395762988567
#
#
# At random state 993, the training academy is:-0.47108201286849294
# At random state 993, the training academy is:-0.3908863319064685
#
#
# At random state 994, the training academy is:-0.4598210769252731
# At random state 994, the training academy is:-0.4499782601503035
#
#
# At random state 995, the training academy is:-0.44841783625202125
# At random state 995, the training academy is:-0.4927134359372486
#
#
# At random state 996, the training academy is:-0.4641521518214502
# At random state 996, the training academy is:-0.430983921709705
#
#
# At random state 997, the training academy is:-0.46323495723355146
# At random state 997, the training academy is:-0.4386827169306775
#
#
# At random state 998, the training academy is:-0.46225143510588607
# At random state 998, the training academy is:-0.4424980377354689
#
#
# At random state 999, the training academy is:-0.45589861002658894
# At random state 999, the training academy is:-0.46521091258009006

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=76)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.4584806464247724

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold2 the cv score is 0.4317882863991056 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724
#
#
# At cross fold3 the cv score is 0.40541365257388495 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724
#
#
# At cross fold4 the cv score is 0.2466838279156109 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724
#
#
# At cross fold5 the cv score is 0.32224965144653145 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724
#
#
# At cross fold6 the cv score is 0.2613952643954915 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724
#
#
# At cross fold7 the cv score is 0.35124258121161606 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724
#
#
# At cross fold8 the cv score is 0.2477893317249081 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724
#
#
# At cross fold9 the cv score is 0.33357788675180894 and accuracy score for training is -0.441654697909561and accuracy for the testing is 0.4584806464247724

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test,y=pred_test,color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha': [.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls = Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)
lss=r2_score(target_test,pred_ls)
lss
# Out:
# 0.4569163840816769

# %%
cv_score=cross_val_score(ls,features,target,cv=2)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.43674917479142655

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="log2")
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision=rf.predict(features_test)
rfs=r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,features,target,cv=2)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 49.55920797281749
# Cross Val Score: 48.53064647311362

# %%
import pickle
filename='abalone.pkl'
pickle.dump(rf,open(filename,'wb'))
